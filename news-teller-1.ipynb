# %%
from newsapi import NewsApiClient

newsapi = NewsApiClient(api_key='iamnotgonnaputthere')


# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='business',
#                                           sources='the-times-of-india',
#                                           category='business',
                                          language='en',
#                                           country='in',
#                                           page = 1
                                         )

# %%
top_headlines

# %%
top_toi = newsapi.get_everything(
                                          sources='the-times-of-india',                        
                                          language='en',
                                          page = 1
)


from win32com.client import Dispatch
def speak(srt,x):
    
    speak = Dispatch("SAPI.SpVoice")
    speak.Speak(srt)
    
if __name__ == '__main__':
    for i in range(3):
        x = top_headlines
        speak(("NEWS" + str(i + 1) + "is" + (x["articles"][i]["title"])),x)

# %%
top_toi
# Out:
# {'status': 'ok',
#  'totalResults': 19633,
#  'articles': [{'source': {'id': 'the-times-of-india',
#     'name': 'The Times of India'},
#    'author': 'ET Online',
#    'title': "Moody's improves India's outlook to 'stable'",
#    'description': 'Moody\'s also affirmed India\'s sovereign credit rating at Baa3 -- -- which is the lowest investment grade, just a notch above junk status. "Moody\'s Investors Service has today changed the outlook on the Government of India\'s ratings to stable from negative and…',
#    'url': 'https://economictimes.indiatimes.com/news/economy/indicators/moodys-improves-indias-outlook-to-stable/articleshow/86784228.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-86784233,width-1070,height-580,imgsize-46964,overlay-economictimes/photo.jpg',
#    'publishedAt': '2021-10-05T13:50:05Z',
# ...
